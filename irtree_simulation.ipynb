# %% [markdown]
# <a href="https://colab.research.google.com/github/tylerjamesryan/Simulation/blob/master/irtree_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if (!require(mirt)) {
  install.packages("mirt")
} else {
  library(mirt)
}

library(Matrix)
library(parallel)

par_bias <- function(true_par, est_par) {
  return(mean(est_par - true_par, na.rm = T))
}

par_SE <- function(true_par, est_par) {
  return(sqrt(mean((est_par - mean(est_par))^2)))
}

par_RMSE <- function(true_par, est_par) {
  return(sqrt((mean((est_par - true_par)^2))))
}

par_fit <- function(pars) {
  pbias <- par_bias(pars[, "true"], pars[,"model"])
  pRMSE <- par_RMSE(pars[, "true"], pars[,"model"])
  pSE <- par_SE(pars[, "true"], pars[,"model"])
  return(c("Bias" = pbias, "RMSE" = pRMSE, "SE" = pSE))
}

dendrify_item <- function(x, tmat) {
  if (min(x) < 1) { # check that minimum item score > 0
    x + (1 - min(x)) # make minimum item score = 1 if need be
  }
  if (is.null(colnames(tmat))) { # assign node col names if none present in tmat
    colnames(tmat) <- paste0("node_", 1:ncol(tmat)) 
  }
  return(tmat[x, ]) # index row of tmat by item response integer/vector x
}

dendrify <- function(x, tmat, long = FALSE) {
  J <- ncol(x) # number of items
  N <- nrow(x) # number of respondents
  K <- ncol(tmat) # number of latent variables
  X <- matrix(nrow = N, ncol = J * K,
              dimnames = list(1:N, 1:(J*K)))
  for (i in 1:J) {
    x_i <- dendrify_item(x[, i], tmat)
    X[, c((i + J * 1:K) - J)] <- x_i
    colnames(X)[c((i + J * 1:K) - J)] <- paste0(colnames(x_i), "_", "i", i)
  }
  if (long) {
    c_names <- rep(colnames(X), each = N)
    c_names <- do.call("rbind", stringr::str_split(c_names, "_i"))
    colnames(c_names) <- c("node", "item")
    id <- rep(1:N, J*K)
    response <- matrix(c(X), N*J*K, 1)
    X <- cbind.data.frame(id, c_names, "response" = response)
  }
  return(X)
}

de_dendrify <- function(data, tmat) {
  M <- nrow(tmat)
  N <- nrow(data)
  JK <- ncol(data)
  K <- ncol(tmat)
  J <- JK / K
  data_new <- matrix(NA, N, J, dimnames = list(1:N, paste0("i", 1:J)))
  tmat_cond <- matrix(as.numeric(rownames(tmat)), nrow = M)
  rownames(tmat_cond) <- apply(tmat, 1, function(m) paste0(m, collapse = ""))
  for (j in 1:J) {
    data_j <- data[, ((J * 0:(K-1)) + j)]
    data_j_collapse <- apply(data_j, 1, function(i) paste0(i, collapse = ""))
    data_new[, j] <- tmat_cond[data_j_collapse, ]
  }
  return(data_new)
}

grm_data_gen <- function(alpha, beta, theta, return_prob = F) {
  n <- nrow(theta)
  j <- nrow(beta)
  m <- ncol(beta)
  k <- ncol(theta)
  aTh <- theta %*% t(alpha)
  aTh_m <- aTh %*% t(as.matrix(Matrix::bdiag(replicate(j, matrix(1, nrow = m, ncol = 1), simplify = F))))
  alpha_m <- alpha %*% as.matrix(Matrix::bdiag(replicate(k, matrix(1, ncol = m), simplify = F)))
  beta_m <- beta %*% do.call(cbind, replicate(k, diag(m), simplify = F))
  B_m <- alpha_m * beta_m
  B_m_n <- matrix(1, ncol = 1, nrow = n) %*% t(matrix(c(t(B_m %*% t(do.call(cbind, replicate(k, diag(m), simplify = F)))))))
  Z <- aTh_m - B_m_n
  brf <- 1 / (1 + exp(-Z))
  brf_m <- matrix(c(t(brf)), ncol = m, byrow = T)
  Pr_m <- cbind(1, brf_m) - cbind(brf_m, 0)
  response <- apply(Pr_m, 1, function(pr) sample(1:(m + 1), 1, replace = F, prob = pr))
  response <- matrix(response, ncol = j, nrow = n, byrow = T)
  if (return_prob) {
    Pr_m <- split.data.frame(Pr_m, rep(1:j, each = n))
    return(list("response" = response, "prob" = Pr_m))
  } else {
    return(response)
  }
}

irtree_data_gen <- function(alpha, beta, theta, T_matrix, return_prob = F) {
  n <- nrow(theta <- as.matrix(theta))
  j <- nrow(as.matrix(beta))
  k <- ncol(as.matrix(theta))
  q <- ncol(T_matrix)
  j_q <- j/q
  m <- nrow(T_matrix)
  T_matrix_rev <- abs(T_matrix - 1) # convert 0s to 1s and 1s to 0s
  
  # multiply alpha * beta and create an n x j*3 matrix of weighted difficulty parameters
  # this is overly complex, need to simplify
  d <- matrix(sqrt(rowSums(alpha * alpha))) %*% matrix(1, 1, ncol(beta)) * beta
  B <- matrix(1, ncol = j, nrow = n) %*% diag(c(d %*% matrix(1, nrow = ncol(beta))))
  
  # multiply alpha * theta and create an n x j*3 matrix of weighted thetas
  aTH <- (theta %*% t(alpha))
  
  # calculate ability - item difficulty discrepancy
  Z <- aTH - B
  
  # estimate response probabilities for a given node
  Pr <- 1 / (1 + exp(-Z))
  
  response <- matrix(nrow = n, ncol = j_q)
  probs <- vector("list", j_q)
  # iterate through items
  for (i in 1:j_q) {
    
    # matrix of possible response options for a given item
    response_options <- matrix(nrow = n, ncol = m)
    
    # selection probabilities for a given item for all nodes
    i_nodes <- (i + j_q*(1:q)) - j_q
    Pr_i <- Pr[, i_nodes]
    
    # iterate through response options
    for (r in 1:m) {
      
      # create an n x 3 matrix for a given response option from the T matrix
      T_matrix_rev_r <- matrix(1, n) %*% T_matrix_rev[r, , drop = F]
      
      # code probabilities according to T matrix and multiply across nodes for overall response probability
      response_options[, r] <- apply(abs(Pr_i - T_matrix_rev_r), 1, prod, na.rm = T)
    }
    probs[[i]] <- response_options
    # draw samples from response proabilities for a given item
    response[, i] <- apply(response_options, 1, function(x) sample(1:m, 1, prob = x))
  }
  
  # create item names
  colnames(response) <- paste0("i", 1:j_q)
  
  dendrified_response <- dendrify(response, T_matrix)
  ret <- list("Likert" = response, "Tree" = dendrified_response)
  if (return_prob) {
    ret <- c(ret, list("Likert_prob" = probs))
  }
  return(ret)
}

irtree_mpp_predict <- function(mod, newdata = NULL, T_matrix = NULL) {
  require(mirt)
  if (is.null(T_matrix)) {
    T_matrix <- matrix(c(0, 0, 1,
                         0, 0, 0,
                         1, NA, NA,
                         0, 1, 0,
                         0, 1, 1),
                       nrow = 5, byrow = T)
  }
  if (!is.null(newdata)) {
    thetas <- do.call("rbind", lapply(1:nrow(newdata), function(i) 
      fscores(mod, response.pattern = newdata[i,], 
              append_response.pattern = F)))
    thetas <- thetas[, -grep("SE_", colnames(thetas)), drop = F]
  } else {
    thetas <- fscores(mod, QMC = T)
  }
  tree_J <- extract.mirt(mod, "nitems")
  K <- ncol(T_matrix)
  M <- nrow(T_matrix)
  J <- tree_J / K
  n <- nrow(as.matrix(thetas))
  tree_item_names <- extract.mirt(mod, "itemnames")
  Pr <- matrix(nrow = n, ncol = tree_J,
               dimnames = list(1:n, tree_item_names))
  for (i in 1:tree_J) {
    item_j <- extract.item(x = mod, item = i)
    Pr[, i] <- expected.item(x = item_j, Theta = thetas)
  }
  
  response <- matrix(nrow = n, ncol = J, dimnames = list(1:n, paste0("i", 1:J)))
  T_matrix <- abs(T_matrix - 1) # convert 0s to 1s and 1s to 0s
  
  
  # recode tree data into likert data
  rs_probs <- vector(mode = "list", length = J)
  for (i in 1:J) {
    pseud_i <- i + rep(J, K) * (0:(K-1))
    response_options <- matrix(nrow = n, ncol = M)
    Pr_i <- Pr[, pseud_i]
    for (r in 1:M) {
      
      # create an n x 3 matrix for a given response option from the T matrix
      T_matrix_r <- matrix(1, nrow(thetas)) %*% T_matrix[r, ]
      
      # code probabilities according to T matrix and multiply across nodes for overall response probability
      response_options[, r] <- apply(abs(Pr_i - T_matrix_r), 1, prod, na.rm = T)
    }
    
    # draw samples from response proabilities for a given item
    response[, i] <- apply(response_options, 1, function(x) sum(x * 1:M))
    rs_probs[[i]] <- response_options
  }
  
  # create item names
  colnames(response) <- names(rs_probs) <- paste0("i", 1:J)
  return(list("rs" = response, "tree" = round(Pr), "rs_prob" = rs_probs, "tree_prob" = Pr))
}

grm_predict <- function(mod, newdata = NULL, theta = NULL) {
  j <- extract.mirt(mod, "nitems")
  
  if (!is.null(newdata)) {
    observed <- newdata
    theta <- do.call("rbind", lapply(1:nrow(newdata), function(i) 
      fscores(mod, response.pattern = newdata[i,], 
              append_response.pattern = F)))
    theta <- theta[, -grep("SE_", colnames(theta)), drop = F]
    
  } else if (is.null(theta)) {
    observed <- extract.mirt(mod, "data")
    theta <- fscores(mod)
  }
  
  items <- lapply(1:j, function(i) extract.item(mod, item = i))
  pred <- sapply(1:j, function(i) expected.item(items[[i]], theta, min = 1))
  colnames(pred) <- colnames(newdata)
  return(pred)
}

rorme <- function(observed, predicted, theta = NULL) {
  if (!all(dim(observed) == dim(predicted))) {
    stop("Observed and Predicted matrices do not have the same dimensions")
  }
  n <- nrow(observed)
  j <- ncol(observed)
  rmse1 <- sqrt(mean((observed - predicted)^2))
  rmse0 <- sqrt(mean((mean(observed) - predicted)^2))
  rse <- sum((observed - predicted)^2) / sum(((mean(observed) - observed))^2)
  rorme <- rmse1 / rmse0
  modelfit <- c("RMSE" = rmse1, "RSE" = rse, "RORME" = rorme)
  
  item_rmse1 <- sqrt(colMeans((observed - predicted)^2))
  item_rmse0 <- sqrt(colMeans((matrix(1, n, 1) %*% colMeans(observed) - predicted)^2))
  item_rorme <- item_rmse1 / item_rmse0
  itemfit <- list("RMSEi" = item_rmse1, "RORMEi" = item_rorme)
  person_rmse1 <- sqrt(rowMeans((observed - predicted)^2))
  person_rmse0 <- sqrt(rowMeans((rowMeans(observed) %*% matrix(1, 1, j) - predicted)^2))
  person_rorme <- person_rmse1 / person_rmse0
  personfit <- list("RMSEp" = person_rmse1, "RORMEp" = person_rorme)
  
  return(list("modelfit" = modelfit, "itemfit" = itemfit, "personfit" = personfit))
}

extract_tree_pars <- function(mod, alpha, beta, theta, phi, iter = NULL, node_names = NULL) {
  j <- nrow(as.matrix(beta))
  n <- nrow(theta)
  K <- ncol(theta)
  j_k <- j/K
  if (class(mod) == "try-error") {
    item_pars <- matrix(NA, nrow = j, ncol = K + 3,
                        dimnames = list(1:j, c(paste0("a", 1:K), "d", "g", "u")))
    item_pars <- as.data.frame(item_pars)
    item <- rep(1:j_k, K)
  } else { 
    mod_coef <- coef(mod, simplify = T)
    item_pars <- as.data.frame(mod_coef$items)
    item <- gsub("\\.\\w\\d{1,}", "", row.names(item_pars))
    item <- as.numeric(gsub("\\D", "", item))
  }
  item_pars$item <- item
  if (is.null(node_names)) {
    node <- gsub("i\\d{1,}\\.", "", row.names(item_pars))
    node <- gsub("\\d{1,}", "", node)
  } else {
    node <- rep(node_names, each = j_k)
  }
  item_pars$node <- node
  #item_pars <- item_pars[order(item_pars$node, item_pars$item), ]
  # alpha parameters
  
  a_true <- rowSums(alpha)
  a_mod  <- rowSums(item_pars[grep("a\\d", names(item_pars))])
  a_pars <- cbind.data.frame("n" = n, "j" = j_k, "iter" = iter,
                             "node" = item_pars$node, 
                             "item" = item_pars$item, 
                             "true" = a_true, 
                             "model" = a_mod)
  
  # beta parameters
  
  b_true <- rowSums(as.matrix(beta))
  b_mod  <- rowSums(item_pars[c("d")]) / -a_mod
  b_pars <- cbind.data.frame("n" = n, "j" = j_k, "iter" = iter,
                             "node" = item_pars$node, 
                             "item" = item_pars$item, 
                             "true" = b_true, 
                             "model" = b_mod)
  
  # latent covariances
  
  phi_true <- phi[lower.tri(phi)]
  phi_mod <- cov2cor(mod_coef$cov)[lower.tri(mod_coef$cov)]
  phi_pars <- cbind.data.frame("n" = n, "j" = j, "iter" = iter,
                               "true" = phi_true,
                               "model" = phi_mod)
  
  if (!is.null(theta)) {
    if (class(mod) == "try-error") {
      EAP <- matrix(NA, n, K)
    } else {
      EAP <- fscores(mod, QMC = T)
    }
    theta_param <- cbind.data.frame("n" = n, "j" = j_k, "iter" = iter,
                                    "node" = rep(unique(node), each = n),
                                    "id" = rep(1:n, K),
                                    "model" = c(EAP),
                                    "true" = c(as.matrix(theta)))
  }
  
  pars_list <- list("alpha" = a_pars, "beta" = b_pars, "phi" = phi_pars, "theta" = theta_param)
  
  return(pars_list)
}

append_sim <- function(sims, sim) {
  if (length(sims) != length(sim)) {
    stop("Doesn't Work Bub...")
  }
  for (l in 1:length(sim)) {
    sims[[l]] <- rbind(sims[[l]], sim[[l]])
  }
  return(sims)
}

rlkj <- function (K, n = 1, eta = 1) {
  # taken from rethinking package (McElreath, 2020)
  stopifnot(is.numeric(K), K >= 2, K == as.integer(K))
  stopifnot(eta > 0)
  f <- function() {
    alpha <- eta + (K - 2)/2
    r12 <- 2 * rbeta(1, alpha, alpha) - 1
    R <- matrix(0, K, K)
    R[1, 1] <- 1
    R[1, 2] <- r12
    R[2, 2] <- sqrt(1 - r12^2)
    if (K > 2) 
      for (m in 2:(K - 1)) {
        alpha <- alpha - 0.5
        y <- rbeta(1, m/2, alpha)
        z <- rnorm(m, 0, 1)
        z <- z/sqrt(crossprod(z)[1])
        R[1:m, m + 1] <- sqrt(y) * z
        R[m + 1, m + 1] <- sqrt(1 - y)
      }
    return(crossprod(R))
  }
  R <- replicate(n, f())
  if (dim(R)[3] == 1) {
    R <- R[, , 1]
  }
  else {
    R <- aperm(R, c(3, 1, 2))
  }
  return(R)
}

get_irtree_data <- function(N, J, tmat, type = "2PL", pars = TRUE) {
  K <- ncol(tmat)
  M <- nrow(tmat)
  alpha <- (diag(K) %x% matrix(1, J))
  if(type == "2PL") {
    alpha <- diag(rlnorm(J*K, .22, .33)) %*% alpha
  } 
  beta <- matrix(rnorm(J*K, 0, 1))
  phi <- rlkj(K = K)
  theta <- replicate(K, rnorm(N, 0, 1)) %*% chol(phi)
  X <- irtree_data_gen(alpha, beta, theta, tmat)
  if (pars) {
    X$pars <- list(alpha = alpha, beta = beta, phi = phi, theta = theta)
  }
  return(X)
}

lmat2mirtmod <- function(lmat, J, COV) {
  require(mirt)
  if (missing(COV)) {
    COV <- diag(ncol(lmat))
    COV <- upper.tri(COV)
  }
  return(mirt.model(abs(lmat) > 0, COV = COV))
}

get_irtree_sim_results <- function() {
  rds_files <- list.files("results/", "\\.rds", full.names = T)
  file_names <- gsub("results\\/\\/|\\.rds", "", rds_files)
  L <- length(rds_files)
  models_list <- vector("list", L)
  pars_list <- vector("list", L)
  for (f in 1:L) {
    file <- readRDS(rds_files[f])
    L_f <- length(file)
    models_list_f <- vector("list", L_f)
    pars_list_f <- vector("list", L_f)
    for (i in 1:L_f) {
      models_list_f[[i]] <- file[[i]]$model
      pars_list_f[i] <- list(file[[i]]$pars)
    }
    models_list[[f]] <- models_list_f
    pars_list[[f]] <- pars_list_f
  }
  names(models_list) <- names(pars_list) <- file_names
  return(list("models" = models_list, "pars" = pars_list))
}



irtree_mpp_predict <- function(mod, newdata = NULL, T_matrix = NULL) {
  require(mirt)
  if (is.null(T_matrix)) {
    T_matrix <- matrix(c(0, 0, 1,
                         0, 0, 0,
                         1, NA, NA,
                         0, 1, 0,
                         0, 1, 1),
                       nrow = 5, byrow = T)
  }
  if (!is.null(newdata)) {
    thetas <- do.call("rbind", lapply(1:nrow(newdata), function(i) 
      fscores(mod, response.pattern = newdata[i,], 
              append_response.pattern = F)))
    thetas <- thetas[, -grep("SE_", colnames(thetas)), drop = F]
  } else {
    thetas <- fscores(mod, QMC = T)
  }
  tree_J <- extract.mirt(mod, "nitems")
  K <- ncol(T_matrix)
  M <- nrow(T_matrix)
  J <- tree_J / K
  n <- nrow(as.matrix(thetas))
  tree_item_names <- extract.mirt(mod, "itemnames")
  Pr <- matrix(nrow = n, ncol = tree_J,
               dimnames = list(1:n, tree_item_names))
  for (i in 1:tree_J) {
    item_j <- extract.item(x = mod, item = i)
    Pr[, i] <- expected.item(x = item_j, Theta = thetas)
  }
  
  response <- matrix(nrow = n, ncol = J, dimnames = list(1:n, paste0("i", 1:J)))
  T_matrix <- abs(T_matrix - 1) # convert 0s to 1s and 1s to 0s
  
  
  # recode tree data into likert data
  rs_probs <- vector(mode = "list", length = J)
  for (i in 1:J) {
    pseud_i <- i + rep(J, K) * (0:(K-1))
    response_options <- matrix(nrow = n, ncol = M)
    Pr_i <- Pr[, pseud_i]
    for (r in 1:M) {
      
      # create an n x 3 matrix for a given response option from the T matrix
      T_matrix_r <- matrix(1, nrow(thetas)) %*% T_matrix[r, ]
      
      # code probabilities according to T matrix and multiply across nodes for overall response probability
      response_options[, r] <- apply(abs(Pr_i - T_matrix_r), 1, prod, na.rm = T)
    }
    
    # draw samples from response proabilities for a given item
    response[, i] <- apply(response_options, 1, function(x) sum(x * 1:M))
    rs_probs[[i]] <- response_options
  }
  
  # create item names
  colnames(response) <- names(rs_probs) <- paste0("i", 1:J)
  return(list("rs" = response, "tree" = round(Pr), "rs_prob" = rs_probs, "tree_prob" = Pr))
}


vech_item_pars <- function(mod, true_pars = NULL) {
  fit_pars <- as.data.frame(coef(mod, printSE = mod@Options$SE, as.data.frame = T))
  par_id <- as.data.frame(stringr::str_split_fixed(row.names(fit_pars), "\\.", n = 2))
  fit_pars <- cbind(par_id, fit_pars)
  names(fit_pars) <- c("id", "par", "est", "SE")
  if (!is.null(true_pars)) {
    fit_pars$true <- vech_pars(tau = true_pars$tau, group_pars = true_pars$group_pars)
  } else {
    return(cbind(fit_pars, "true" = NA))
  }
  
  return(fit_pars)
}

vech_person_pars <- function(mod, true_theta) {
  N <- nrow(as.matrix(true_theta))
  K <- ncol(as.matrix(true_theta))
  QMC <- K > 2
  con <- try(v_fitted_th <- fscores(mod, QMC = QMC, full.scores.SE = T))
  if (class(con)[1] == "try-error") {
    v_fitted_th <- matrix(NA, N*(K*2), 1)
  }
  v_true_theta <- c(true_theta)
  
  person_pars <- data.frame(
    "id" = paste0("p_", rep(1:N, times = K)),
    "par" = paste0("th_", rep(1:K, each = N)),
    "est" = c(v_fitted_th[,1:K]),
    "SE" = c(v_fitted_th[,(K+1):(K*2)]),
    "true" = v_true_theta
  )
  return(person_pars)
}

vech_pars <- function(tau, group_pars) {
  K <- length(grep("\\ba", colnames(tau)))
  M <- length(grep("\\bd", colnames(tau)))
  tau[, (K+1):(K+M)] <- matrix(-1*sqrt(rowSums(tau[,1:K] * tau[,1:K]))) * tau[, (K+1):(K+M)]
  
  return(c(c(t(tau)), c(group_pars$zeta), group_pars$sigma[lower.tri(group_pars$sigma, diag = T)]))
}

get_pars <- function(mod, true_pars, theta) {
  if (missing(true_pars)) {
    person_pars <- vech_person_pars(mod, theta)
    con <- check_converged(mod)
    df_pars <- cbind.data.frame(person_pars, "converged" = con)
    return(df_pars)
  }
  item_pars <- vech_item_pars(mod, true_pars)
  person_pars <- vech_person_pars(mod, theta)
  df_pars <- rbind(item_pars, person_pars)
  
  con <- check_converged(mod)
  df_pars$converged <- con
  return(df_pars)
}

check_converged <- function(mod) {
  mod@OptimInfo$converged
}




make_tau <- function(alpha, beta, theta, g = 0, u = 0) {
  alpha <- as.matrix(alpha)
  colnames(alpha) <- paste0("a", 1:ncol(alpha))
  beta <- matrix(-sqrt(rowSums(alpha * alpha)) * beta)
  colnames(beta) <- paste0("d", 1:ncol(beta))
  tau <- cbind(alpha, beta, "g" = g, "u" = u)
  return(tau)
}

gen_data_f <- function(n, j, b, tmat) {
  K <- ncol(tmat)
  
  phi <- diag(K)
  omega <- diag(K)
  sigma <- omega %*% phi %*% omega
  zeta <- matrix(rep(0, K))
  group_pars <- list("phi" = phi, "omega" = omega,
                     "sigma" = sigma, "zeta" = zeta)
  
  beta <- matrix(c(rnorm(j, b, 1), rnorm(j*(K-1), 0, 1)))
  alpha <- as.matrix(bdiag(replicate(K, rep(1, j), simplify = F)))
  #alpha <- as.matrix(bdiag(replicate(K, rlnorm(j, 0, .25), simplify = F)))
  theta <- replicate(K, rnorm(n, 0, 1)) %*% chol(sigma)
  tau <- make_tau(alpha, beta, theta)
  
  Y <- irtree_data_gen(alpha, beta, theta, tmat)
  list("Y" = Y, "tau" = tau, "group_pars" = group_pars, "theta" = theta)
}

mod_f <- function(Y, ...) {
  model <- lmat2mirtmod(Y$tau[,grep("\\ba", colnames(Y$tau))], COV = F)
  try(fit <- mirt(Y$Y$Tree, model = model, ...))
  return(fit)
}

fit_fun <- function(n, j, b, tmat, i) {
  i_check <- TRUE
  while (i_check) {
    Y <- gen_data_f(n = n, j = j, b = b, tmat = tmat)
    i_check <- any(!apply(Y$Y$Tree, 2, function(i) length(unique(na.omit(i)))) > 1)
  }
  fit <- mod_f(Y, itemtype = "Rasch", method = "MHRM", technical = list(NCYCLES = 1e5), SE = T)
  v_pars <- get_pars(mod = fit, true_pars = Y[2:3], theta = Y$theta)
  v_pars <- cbind("n" = n, 
                  "j" = j,
                  "iter" = i, 
                  "b1" = b,
                  "tmat" = ncol(tmat)-1,
                  v_pars)
  v_pars
}

tmat1 <- matrix(c(0,NA,
                  1, 0,
                  1, 1), 
                nrow = 3, byrow = T,
                dimnames = list(1:3, c("n1", "n2")))

tmat2 <- matrix(c(0,NA,NA,
                  1, 0,NA,
                  1, 1, 0,
                  1, 1, 1), 
                nrow = 4, byrow = T,
                dimnames = list(1:4, c("n1", "n2", "n3")))

tmat3 <- matrix(c(0,NA,NA,NA,
                  1, 0,NA,NA,
                  1, 1, 0,NA,
                  1, 1, 1, 0,
                  1, 1, 1, 1), 
                nrow = 5, byrow = T,
                dimnames = list(1:5, c("n1", "n2", "n3", "n4")))
# Out:
# Loading required package: mirt
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mirt’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘permute’, ‘GPArotation’, ‘vegan’, ‘Deriv’, ‘dcurver’, ‘RcppArmadillo’

# %%
library(mirt)
rdf <- data.frame()

# %%
bs <- c(-2, 0, 2)
tmats <- list(tmat1, tmat2, tmat3)
iters <- 6
Ns <- c(500, 1000)
Js <- c(10, 20)
start_iter <- 1
end_iter <- 10
for (i in start_iter:end_iter) {
  for (b in bs) {
    for (n in Ns) {
      for (j in Js) {
        for (tmat in tmats) {

          t1 <- Sys.time()
          fit <- fit_fun(n, j, b, tmat, i)
          fit$simID <- paste0("n_", n, "j_", j, "b_", b, "tmat_", fit$tmat[1], "iter_", i)
          rdf <- rbind(rdf, fit)
          t2 <- Sys.time()
          cat("n =", n, "; j =", j, "; b =", b, "; iter =", i, "; time =", (t2 - t1)[[1]], "\n")
          
        }
      }
    }
  }
}
# Out:
# Stage 3 = 30, LL = -5548.9, AR(0.90) = [0.38], gam = 0.0142, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 1 ; time = 17.28307
# Stage 3 = 34, LL = -7545.3, AR(0.55) = [0.42], gam = 0.0129, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 1 ; time = 25.98505
# Stage 3 = 93, LL = -8355.7, AR(0.46) = [0.42], gam = 0.0060, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 1 ; time = 36.99604
# Stage 3 = 34, LL = -9485.4, AR(0.81) = [0.33], gam = 0.0129, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 1 ; time = 28.1971
# Stage 3 = 55, LL = -12071.7, AR(0.26) = [0.49], gam = 0.0089, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 1 ; time = 46.45131
# Stage 3 = 112, LL = -14522.9, AR(0.40) = [0.40], gam = 0.0052, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 1 ; time = 1.107929
# Stage 3 = 28, LL = -11079.5, AR(0.95) = [0.42], gam = 0.0150, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 1 ; time = 30.03315
# Stage 3 = 37, LL = -14606.6, AR(0.61) = [0.39], gam = 0.0121, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 1 ; time = 46.58362
# Stage 3 = 69, LL = -17366.2, AR(0.50) = [0.39], gam = 0.0075, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 1 ; time = 1.07929
# Stage 3 = 19, LL = -19851.1, AR(0.87) = [0.35], gam = 0.0203, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 1 ; time = 51.93539
# Stage 3 = 37, LL = -25235.6, AR(0.50) = [0.33], gam = 0.0121, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 1 ; time = 1.371188
# Stage 3 = 78, LL = -28901.9, AR(0.40) = [0.35], gam = 0.0068, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 1 ; time = 1.936543
# Stage 3 = 41, LL = -5384.3, AR(0.88) = [0.41], gam = 0.0112, Max-Change = 0.0004
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 1 ; time = 17.55252
# Stage 3 = 72, LL = -6778.6, AR(0.63) = [0.37], gam = 0.0073, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 1 ; time = 27.4555
# Stage 3 = 118, LL = -7958.5, AR(0.48) = [0.43], gam = 0.0050, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 1 ; time = 39.34025
# Stage 3 = 36, LL = -9616.4, AR(0.60) = [0.41], gam = 0.0124, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 1 ; time = 30.43424
# Stage 3 = 73, LL = -11505.4, AR(0.46) = [0.40], gam = 0.0072, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 1 ; time = 47.94314
# Stage 3 = 147, LL = -13115.0, AR(0.35) = [0.39], gam = 0.0042, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 1 ; time = 1.16846
# Stage 3 = 36, LL = -10614.4, AR(1.01) = [0.40], gam = 0.0124, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 1 ; time = 31.68568
# Stage 3 = 43, LL = -14176.9, AR(0.62) = [0.40], gam = 0.0108, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 1 ; time = 47.84013
# Stage 3 = 60, LL = -15788.0, AR(0.50) = [0.41], gam = 0.0084, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 1 ; time = 1.090606
# Stage 3 = 36, LL = -18164.9, AR(0.68) = [0.42], gam = 0.0124, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 1 ; time = 53.47569
# Stage 3 = 69, LL = -23337.4, AR(0.50) = [0.33], gam = 0.0075, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 1 ; time = 1.411175
# Stage 3 = 127, LL = -25037.1, AR(0.50) = [0.32], gam = 0.0047, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 1 ; time = 1.979323
# Stage 3 = 192, LL = -3338.2, AR(1.38) = [0.44], gam = 0.0035, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 1 ; time = 18.32119
# Stage 3 = 269, LL = -4367.2, AR(0.90) = [0.39], gam = 0.0027, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 1 ; time = 29.41954
# Stage 3 = 234, LL = -5463.2, AR(0.57) = [0.38], gam = 0.0030, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 1 ; time = 40.5722
# Stage 3 = 91, LL = -6298.4, AR(0.88) = [0.42], gam = 0.0061, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 1 ; time = 29.39052
# Stage 3 = 157, LL = -8349.3, AR(0.57) = [0.37], gam = 0.0040, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 1 ; time = 47.76127
# Stage 3 = 454, LL = -7807.9, AR(0.59) = [0.40], gam = 0.0018, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 1 ; time = 1.414526
# Stage 3 = 62, LL = -7636.4, AR(1.35) = [0.39], gam = 0.0081, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 1 ; time = 29.95129
# Stage 3 = 121, LL = -10050.9, AR(0.71) = [0.36], gam = 0.0049, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 1 ; time = 47.08736
# Stage 3 = 478, LL = -10699.6, AR(0.77) = [0.40], gam = 0.0017, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 1 ; time = 1.319995
# Stage 3 = 62, LL = -11760.7, AR(1.03) = [0.36], gam = 0.0081, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 1 ; time = 52.96497
# Stage 3 = 152, LL = -14884.3, AR(0.72) = [0.40], gam = 0.0041, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 1 ; time = 1.449557
# Stage 3 = 430, LL = -16993.8, AR(0.53) = [0.41], gam = 0.0019, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 1 ; time = 2.329745
# Stage 3 = 30, LL = -5824.9, AR(0.88) = [0.41], gam = 0.0142, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 2 ; time = 16.94723
# Stage 3 = 60, LL = -7261.3, AR(0.58) = [0.39], gam = 0.0084, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 2 ; time = 26.25526
# Stage 3 = 82, LL = -8461.4, AR(0.49) = [0.40], gam = 0.0066, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 2 ; time = 36.77355
# Stage 3 = 30, LL = -9268.4, AR(0.64) = [0.39], gam = 0.0142, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 2 ; time = 28.37642
# Stage 3 = 59, LL = -12203.8, AR(0.26) = [0.49], gam = 0.0085, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 2 ; time = 45.37923
# Stage 3 = 88, LL = -14523.4, AR(0.40) = [0.33], gam = 0.0062, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 2 ; time = 1.093995
# Stage 3 = 24, LL = -10490.3, AR(1.05) = [0.40], gam = 0.0169, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 2 ; time = 30.05905
# Stage 3 = 44, LL = -15128.4, AR(0.62) = [0.40], gam = 0.0106, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 2 ; time = 46.05045
# Stage 3 = 57, LL = -16999.8, AR(0.47) = [0.39], gam = 0.0087, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 2 ; time = 1.062782
# Stage 3 = 17, LL = -19327.0, AR(0.69) = [0.38], gam = 0.0222, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 2 ; time = 51.85699
# Stage 3 = 33, LL = -25442.0, AR(0.50) = [0.34], gam = 0.0132, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 2 ; time = 1.367404
# Stage 3 = 65, LL = -28535.6, AR(0.40) = [0.37], gam = 0.0079, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 2 ; time = 1.894769
# Stage 3 = 46, LL = -5644.3, AR(0.79) = [0.41], gam = 0.0102, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 2 ; time = 17.42216
# Stage 3 = 75, LL = -6924.9, AR(0.62) = [0.39], gam = 0.0070, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 2 ; time = 27.41374
# Stage 3 = 135, LL = -7672.7, AR(0.47) = [0.39], gam = 0.0045, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 2 ; time = 39.3263
# Stage 3 = 43, LL = -9369.7, AR(0.64) = [0.40], gam = 0.0108, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 2 ; time = 29.68761
# Stage 3 = 92, LL = -11896.1, AR(0.45) = [0.39], gam = 0.0060, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 2 ; time = 47.2113
# Stage 3 = 155, LL = -12501.7, AR(0.38) = [0.36], gam = 0.0041, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 2 ; time = 1.135389
# Stage 3 = 22, LL = -11309.3, AR(0.93) = [0.39], gam = 0.0181, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 2 ; time = 30.6466
# Stage 3 = 47, LL = -13700.8, AR(0.65) = [0.38], gam = 0.0101, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 2 ; time = 46.46506
# Stage 3 = 97, LL = -15667.4, AR(0.50) = [0.42], gam = 0.0058, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 2 ; time = 1.089715
# Stage 3 = 25, LL = -18848.0, AR(0.62) = [0.39], gam = 0.0164, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 2 ; time = 52.54611
# Stage 3 = 76, LL = -21551.6, AR(0.45) = [0.38], gam = 0.0070, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 2 ; time = 1.402351
# Stage 3 = 134, LL = -25780.5, AR(0.40) = [0.38], gam = 0.0045, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 2 ; time = 2.013633
# Stage 3 = 106, LL = -3470.8, AR(1.53) = [0.38], gam = 0.0054, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 2 ; time = 17.74585
# Stage 3 = 293, LL = -4488.8, AR(1.07) = [0.36], gam = 0.0025, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 2 ; time = 30.45529
# Stage 3 = 287, LL = -6182.4, AR(0.63) = [0.39], gam = 0.0026, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 2 ; time = 42.26517
# Stage 3 = 121, LL = -6273.4, AR(0.94) = [0.41], gam = 0.0049, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 2 ; time = 30.20238
# Stage 3 = 290, LL = -7607.2, AR(0.57) = [0.38], gam = 0.0025, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 2 ; time = 52.14799
# Stage 3 = 447, LL = -7890.6, AR(0.56) = [0.34], gam = 0.0018, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 2 ; time = 1.403089
# Stage 3 = 66, LL = -8046.5, AR(1.30) = [0.39], gam = 0.0078, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 2 ; time = 30.61529
# Stage 3 = 262, LL = -8314.3, AR(1.03) = [0.41], gam = 0.0027, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 2 ; time = 51.96345
# Stage 3 = 196, LL = -11431.1, AR(0.70) = [0.40], gam = 0.0034, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 2 ; time = 1.142399
# Stage 3 = 62, LL = -13407.5, AR(0.79) = [0.38], gam = 0.0081, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 2 ; time = 52.87981
# Stage 3 = 166, LL = -13497.5, AR(0.66) = [0.36], gam = 0.0039, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 2 ; time = 1.428348
# Stage 3 = 417, LL = -15692.1, AR(0.62) = [0.37], gam = 0.0019, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 2 ; time = 2.293919
# Stage 3 = 34, LL = -5653.8, AR(0.91) = [0.41], gam = 0.0129, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 3 ; time = 17.32953
# Stage 3 = 61, LL = -7120.9, AR(0.61) = [0.37], gam = 0.0082, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 3 ; time = 26.85494
# Stage 3 = 91, LL = -8438.7, AR(0.47) = [0.39], gam = 0.0061, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 3 ; time = 37.40626
# Stage 3 = 29, LL = -9396.0, AR(0.79) = [0.35], gam = 0.0146, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 3 ; time = 28.31461
# Stage 3 = 51, LL = -12210.9, AR(0.50) = [0.34], gam = 0.0095, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 3 ; time = 44.9618
# Stage 3 = 125, LL = -14571.8, AR(0.40) = [0.34], gam = 0.0048, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 3 ; time = 1.093438
# Stage 3 = 25, LL = -11397.5, AR(0.97) = [0.38], gam = 0.0164, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 3 ; time = 30.54473
# Stage 3 = 34, LL = -15073.8, AR(0.59) = [0.39], gam = 0.0129, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 3 ; time = 46.57819
# Stage 3 = 83, LL = -16917.8, AR(0.45) = [0.36], gam = 0.0065, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 3 ; time = 1.0815
# Stage 3 = 14, LL = -19098.8, AR(0.65) = [0.39], gam = 0.0260, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 3 ; time = 51.26742
# Stage 3 = 35, LL = -25256.4, AR(0.50) = [0.34], gam = 0.0126, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 3 ; time = 1.369054
# Stage 3 = 50, LL = -29117.4, AR(0.40) = [0.34], gam = 0.0096, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 3 ; time = 1.905807
# Stage 3 = 64, LL = -5297.3, AR(0.99) = [0.36], gam = 0.0080, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 3 ; time = 17.57952
# Stage 3 = 120, LL = -6461.9, AR(0.77) = [0.40], gam = 0.0049, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 3 ; time = 28.05297
# Stage 3 = 174, LL = -7882.7, AR(0.53) = [0.40], gam = 0.0037, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 3 ; time = 39.61628
# Stage 3 = 56, LL = -9247.8, AR(0.63) = [0.43], gam = 0.0088, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 3 ; time = 29.30403
# Stage 3 = 86, LL = -11412.4, AR(0.45) = [0.40], gam = 0.0064, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 3 ; time = 46.44526
# Stage 3 = 151, LL = -13098.8, AR(0.38) = [0.38], gam = 0.0041, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 3 ; time = 1.132261
# Stage 3 = 33, LL = -10987.4, AR(0.93) = [0.39], gam = 0.0132, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 3 ; time = 30.86926
# Stage 3 = 51, LL = -13788.1, AR(0.62) = [0.41], gam = 0.0095, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 3 ; time = 46.49544
# Stage 3 = 114, LL = -15604.3, AR(0.51) = [0.40], gam = 0.0051, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 3 ; time = 1.105848
# Stage 3 = 41, LL = -19049.5, AR(0.63) = [0.39], gam = 0.0112, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 3 ; time = 53.13895
# Stage 3 = 56, LL = -23715.6, AR(0.50) = [0.36], gam = 0.0088, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 3 ; time = 1.403452
# Stage 3 = 88, LL = -27276.2, AR(0.40) = [0.39], gam = 0.0062, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 3 ; time = 1.962608
# Stage 3 = 97, LL = -3686.0, AR(1.33) = [0.39], gam = 0.0058, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 3 ; time = 18.04686
# Stage 3 = 160, LL = -4910.2, AR(0.82) = [0.33], gam = 0.0040, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 3 ; time = 28.5849
# Stage 3 = 301, LL = -5899.0, AR(0.64) = [0.38], gam = 0.0025, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 3 ; time = 42.17923
# Stage 3 = 139, LL = -6711.7, AR(0.90) = [0.36], gam = 0.0044, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 3 ; time = 31.05667
# Stage 3 = 185, LL = -8098.2, AR(0.64) = [0.35], gam = 0.0036, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 3 ; time = 49.89016
# Stage 3 = 442, LL = -8488.8, AR(0.59) = [0.37], gam = 0.0018, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 3 ; time = 1.396851
# Stage 3 = 80, LL = -7448.6, AR(1.33) = [0.40], gam = 0.0067, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 3 ; time = 31.3364
# Stage 3 = 82, LL = -10380.1, AR(1.05) = [0.41], gam = 0.0066, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 3 ; time = 47.24676
# Stage 3 = 260, LL = -11924.1, AR(0.68) = [0.41], gam = 0.0028, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 3 ; time = 1.193829
# Stage 3 = 43, LL = -13823.6, AR(1.10) = [0.35], gam = 0.0108, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 3 ; time = 52.59503
# Stage 3 = 125, LL = -14977.2, AR(0.68) = [0.38], gam = 0.0048, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 3 ; time = 1.41778
# Stage 3 = 484, LL = -15605.9, AR(0.58) = [0.41], gam = 0.0017, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 3 ; time = 2.549754
# Stage 3 = 35, LL = -5650.4, AR(0.97) = [0.41], gam = 0.0126, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 4 ; time = 17.22811
# Stage 3 = 43, LL = -7437.9, AR(0.66) = [0.33], gam = 0.0108, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 4 ; time = 26.54688
# Stage 3 = 98, LL = -8569.9, AR(0.46) = [0.42], gam = 0.0058, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 4 ; time = 37.72883
# Stage 3 = 32, LL = -8882.9, AR(0.69) = [0.39], gam = 0.0135, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 4 ; time = 28.17806
# Stage 3 = 35, LL = -12810.1, AR(0.39) = [0.39], gam = 0.0126, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 4 ; time = 45.09779
# Stage 3 = 89, LL = -14554.3, AR(0.31) = [0.43], gam = 0.0062, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 4 ; time = 1.090661
# Stage 3 = 19, LL = -10911.2, AR(1.04) = [0.41], gam = 0.0203, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 4 ; time = 30.62479
# Stage 3 = 49, LL = -14640.8, AR(0.60) = [0.41], gam = 0.0098, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 4 ; time = 47.5438
# Stage 3 = 104, LL = -16424.2, AR(0.49) = [0.42], gam = 0.0055, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 4 ; time = 1.096426
# Stage 3 = 19, LL = -19549.1, AR(0.71) = [0.38], gam = 0.0203, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 4 ; time = 51.25951
# Stage 3 = 49, LL = -24035.4, AR(0.42) = [0.39], gam = 0.0098, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 4 ; time = 1.374308
# Stage 3 = 90, LL = -27749.2, AR(0.40) = [0.40], gam = 0.0061, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 4 ; time = 1.971255
# Stage 3 = 46, LL = -5338.0, AR(1.02) = [0.41], gam = 0.0102, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 4 ; time = 17.72107
# Stage 3 = 70, LL = -6749.1, AR(0.60) = [0.39], gam = 0.0074, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 4 ; time = 27.59857
# Stage 3 = 135, LL = -7747.0, AR(0.47) = [0.39], gam = 0.0045, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 4 ; time = 39.26384
# Stage 3 = 45, LL = -8859.3, AR(0.63) = [0.40], gam = 0.0104, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 4 ; time = 29.44005
# Stage 3 = 90, LL = -11848.2, AR(0.44) = [0.39], gam = 0.0061, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 4 ; time = 47.33326
# Stage 3 = 138, LL = -13301.1, AR(0.35) = [0.41], gam = 0.0044, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 4 ; time = 1.13392
# Stage 3 = 45, LL = -10531.7, AR(0.94) = [0.43], gam = 0.0104, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 4 ; time = 31.32483
# Stage 3 = 60, LL = -13263.2, AR(0.67) = [0.40], gam = 0.0084, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 4 ; time = 47.84258
# Stage 3 = 119, LL = -15675.9, AR(0.48) = [0.40], gam = 0.0050, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 4 ; time = 1.12743
# Stage 3 = 34, LL = -18259.7, AR(0.69) = [0.43], gam = 0.0129, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 4 ; time = 53.91937
# Stage 3 = 70, LL = -22080.8, AR(0.46) = [0.38], gam = 0.0074, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 4 ; time = 1.427253
# Stage 3 = 107, LL = -25412.3, AR(0.40) = [0.38], gam = 0.0054, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 4 ; time = 1.997584
# Stage 3 = 139, LL = -3537.4, AR(1.27) = [0.36], gam = 0.0044, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 4 ; time = 18.5965
# Stage 3 = 254, LL = -4058.1, AR(1.01) = [0.40], gam = 0.0028, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 4 ; time = 30.20865
# Stage 3 = 345, LL = -5205.7, AR(0.61) = [0.41], gam = 0.0022, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 4 ; time = 44.1451
# Stage 3 = 141, LL = -6664.3, AR(0.87) = [0.42], gam = 0.0044, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 4 ; time = 31.49904
# Stage 3 = 252, LL = -7057.9, AR(0.74) = [0.38], gam = 0.0028, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 4 ; time = 51.49094
# Stage 3 = 331, LL = -8920.5, AR(0.48) = [0.38], gam = 0.0023, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 4 ; time = 1.253787
# Stage 3 = 82, LL = -6978.4, AR(1.50) = [0.39], gam = 0.0066, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 4 ; time = 31.1544
# Stage 3 = 79, LL = -11099.4, AR(0.76) = [0.40], gam = 0.0068, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 4 ; time = 48.30359
# Stage 3 = 222, LL = -12244.8, AR(0.72) = [0.42], gam = 0.0031, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 4 ; time = 1.174608
# Stage 3 = 83, LL = -12553.9, AR(0.98) = [0.41], gam = 0.0065, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 4 ; time = 55.30473
# Stage 3 = 166, LL = -14993.1, AR(0.69) = [0.41], gam = 0.0039, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 4 ; time = 1.53348
# Stage 3 = 339, LL = -17794.6, AR(0.53) = [0.37], gam = 0.0023, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 4 ; time = 2.296134
# Stage 3 = 30, LL = -5689.4, AR(0.94) = [0.39], gam = 0.0142, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 5 ; time = 17.75033
# Stage 3 = 72, LL = -6822.4, AR(0.66) = [0.39], gam = 0.0073, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 5 ; time = 27.4742
# Stage 3 = 109, LL = -8172.3, AR(0.50) = [0.41], gam = 0.0053, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 5 ; time = 38.63193
# Stage 3 = 18, LL = -9730.3, AR(0.60) = [0.41], gam = 0.0212, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 5 ; time = 28.26537
# Stage 3 = 47, LL = -12593.2, AR(0.40) = [0.38], gam = 0.0101, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 5 ; time = 45.48339
# Stage 3 = 109, LL = -14713.1, AR(0.40) = [0.37], gam = 0.0053, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 5 ; time = 1.094336
# Stage 3 = 23, LL = -10956.0, AR(0.96) = [0.43], gam = 0.0175, Max-Change = 0.0003
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 5 ; time = 30.71756
# Stage 3 = 46, LL = -14833.9, AR(0.61) = [0.40], gam = 0.0102, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 5 ; time = 48.13985
# Stage 3 = 41, LL = -17863.8, AR(0.44) = [0.41], gam = 0.0112, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 5 ; time = 1.08231
# Stage 3 = 23, LL = -19062.9, AR(0.73) = [0.38], gam = 0.0175, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 5 ; time = 51.9471
# Stage 3 = 29, LL = -25391.9, AR(0.50) = [0.35], gam = 0.0146, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 5 ; time = 1.369043
# Stage 3 = 100, LL = -27229.4, AR(0.40) = [0.35], gam = 0.0057, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 5 ; time = 1.952317
# Stage 3 = 41, LL = -5734.1, AR(0.91) = [0.42], gam = 0.0112, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 5 ; time = 17.97611
# Stage 3 = 83, LL = -6826.5, AR(0.61) = [0.40], gam = 0.0065, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 5 ; time = 28.10709
# Stage 3 = 149, LL = -7579.0, AR(0.52) = [0.40], gam = 0.0042, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 5 ; time = 39.57938
# Stage 3 = 57, LL = -8786.2, AR(0.67) = [0.38], gam = 0.0087, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 5 ; time = 29.68415
# Stage 3 = 63, LL = -11519.4, AR(0.44) = [0.38], gam = 0.0080, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 5 ; time = 46.53822
# Stage 3 = 161, LL = -12799.7, AR(0.35) = [0.39], gam = 0.0040, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 5 ; time = 1.140277
# Stage 3 = 35, LL = -10697.0, AR(0.97) = [0.39], gam = 0.0126, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 5 ; time = 30.84435
# Stage 3 = 53, LL = -13854.6, AR(0.67) = [0.39], gam = 0.0092, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 5 ; time = 48.26237
# Stage 3 = 160, LL = -15690.1, AR(0.49) = [0.40], gam = 0.0040, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 5 ; time = 1.138222
# Stage 3 = 35, LL = -19168.7, AR(0.72) = [0.38], gam = 0.0126, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 5 ; time = 53.21687
# Stage 3 = 61, LL = -24083.0, AR(0.44) = [0.39], gam = 0.0082, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 5 ; time = 1.403347
# Stage 3 = 139, LL = -23225.6, AR(0.50) = [0.38], gam = 0.0044, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 5 ; time = 2.008743
# Stage 3 = 126, LL = -3623.6, AR(1.39) = [0.41], gam = 0.0048, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 5 ; time = 18.33735
# Stage 3 = 109, LL = -5238.3, AR(0.81) = [0.39], gam = 0.0053, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 5 ; time = 27.68832
# Stage 3 = 326, LL = -6106.3, AR(0.67) = [0.44], gam = 0.0023, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 5 ; time = 43.50733
# Stage 3 = 115, LL = -6257.7, AR(1.03) = [0.37], gam = 0.0051, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 5 ; time = 30.50997
# Stage 3 = 376, LL = -7511.3, AR(0.75) = [0.38], gam = 0.0021, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 5 ; time = 55.13734
# Stage 3 = 536, LL = -8659.8, AR(0.61) = [0.35], gam = 0.0016, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 5 ; time = 1.463999
# Stage 3 = 80, LL = -8144.7, AR(1.37) = [0.40], gam = 0.0067, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 5 ; time = 31.15546
# Stage 3 = 171, LL = -10662.8, AR(0.91) = [0.41], gam = 0.0038, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 5 ; time = 49.29754
# Stage 3 = 303, LL = -10223.1, AR(0.73) = [0.37], gam = 0.0025, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 5 ; time = 1.202659
# Stage 3 = 82, LL = -12167.3, AR(0.94) = [0.39], gam = 0.0066, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 5 ; time = 53.55943
# Stage 3 = 134, LL = -16315.1, AR(0.68) = [0.39], gam = 0.0045, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 5 ; time = 1.440988
# Stage 3 = 353, LL = -17409.2, AR(0.55) = [0.37], gam = 0.0022, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 5 ; time = 2.279484
# Stage 3 = 34, LL = -5435.2, AR(0.92) = [0.40], gam = 0.0129, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 6 ; time = 17.69029
# Stage 3 = 66, LL = -7197.9, AR(0.61) = [0.41], gam = 0.0078, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 6 ; time = 27.27333
# Stage 3 = 115, LL = -8293.4, AR(0.48) = [0.38], gam = 0.0051, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 6 ; time = 38.30665
# Stage 3 = 34, LL = -9297.7, AR(0.60) = [0.40], gam = 0.0129, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 6 ; time = 28.82417
# Stage 3 = 45, LL = -12710.0, AR(0.50) = [0.35], gam = 0.0104, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 6 ; time = 46.79722
# Stage 3 = 79, LL = -14872.1, AR(0.29) = [0.41], gam = 0.0068, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 6 ; time = 1.088087
# Stage 3 = 26, LL = -10651.6, AR(1.02) = [0.41], gam = 0.0159, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 6 ; time = 30.84055
# Stage 3 = 50, LL = -14423.0, AR(0.62) = [0.39], gam = 0.0096, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 6 ; time = 48.11295
# Stage 3 = 67, LL = -17244.6, AR(0.47) = [0.40], gam = 0.0077, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 6 ; time = 1.091415
# Stage 3 = 17, LL = -18996.7, AR(0.83) = [0.34], gam = 0.0222, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 6 ; time = 52.49235
# Stage 3 = 38, LL = -25299.2, AR(0.50) = [0.33], gam = 0.0119, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 6 ; time = 1.382471
# Stage 3 = 79, LL = -28101.3, AR(0.40) = [0.35], gam = 0.0068, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 6 ; time = 1.963891
# Stage 3 = 58, LL = -5639.3, AR(0.97) = [0.40], gam = 0.0086, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 6 ; time = 18.02636
# Stage 3 = 106, LL = -6954.8, AR(0.65) = [0.40], gam = 0.0054, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 6 ; time = 28.48002
# Stage 3 = 137, LL = -7628.8, AR(0.52) = [0.39], gam = 0.0045, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 6 ; time = 39.63798
# Stage 3 = 40, LL = -9451.7, AR(0.64) = [0.38], gam = 0.0114, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 6 ; time = 29.93843
# Stage 3 = 101, LL = -11147.8, AR(0.48) = [0.36], gam = 0.0056, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 6 ; time = 47.98137
# Stage 3 = 172, LL = -12590.7, AR(0.36) = [0.43], gam = 0.0038, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 6 ; time = 1.155081
# Stage 3 = 34, LL = -10314.4, AR(1.08) = [0.43], gam = 0.0129, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 6 ; time = 31.79891
# Stage 3 = 44, LL = -14199.4, AR(0.59) = [0.40], gam = 0.0106, Max-Change = 0.0004
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 6 ; time = 48.90845
# Stage 3 = 142, LL = -15822.8, AR(0.52) = [0.41], gam = 0.0043, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 6 ; time = 1.136341
# Stage 3 = 39, LL = -18753.9, AR(0.63) = [0.42], gam = 0.0116, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 6 ; time = 52.73268
# Stage 3 = 62, LL = -21890.4, AR(0.45) = [0.39], gam = 0.0081, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 6 ; time = 1.391919
# Stage 3 = 118, LL = -24967.8, AR(0.50) = [0.32], gam = 0.0050, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 6 ; time = 2.007306
# Stage 3 = 61, LL = -3849.8, AR(1.47) = [0.34], gam = 0.0082, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 6 ; time = 18.07047
# Stage 3 = 290, LL = -4221.7, AR(0.92) = [0.37], gam = 0.0025, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 6 ; time = 32.68129
# Stage 3 = 366, LL = -5406.1, AR(0.70) = [0.38], gam = 0.0021, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 6 ; time = 44.85471
# Stage 3 = 146, LL = -5430.5, AR(1.06) = [0.39], gam = 0.0043, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 6 ; time = 31.49736
# Stage 3 = 236, LL = -7665.6, AR(0.63) = [0.42], gam = 0.0030, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 6 ; time = 51.90084
# Stage 3 = 350, LL = -8861.7, AR(0.52) = [0.38], gam = 0.0022, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 6 ; time = 1.328912
# Stage 3 = 73, LL = -7859.1, AR(1.36) = [0.43], gam = 0.0072, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 6 ; time = 31.72664
# Stage 3 = 159, LL = -9007.1, AR(0.90) = [0.38], gam = 0.0040, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 6 ; time = 49.63066
# Stage 3 = 210, LL = -11135.6, AR(0.71) = [0.40], gam = 0.0032, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 6 ; time = 1.167195
# Stage 3 = 88, LL = -12162.3, AR(1.06) = [0.39], gam = 0.0062, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 6 ; time = 54.90227
# Stage 3 = 138, LL = -14988.3, AR(0.68) = [0.42], gam = 0.0044, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 6 ; time = 1.475646
# Stage 3 = 366, LL = -16881.5, AR(0.53) = [0.41], gam = 0.0021, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 6 ; time = 2.278958
# Stage 3 = 34, LL = -5625.7, AR(0.93) = [0.36], gam = 0.0129, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 7 ; time = 17.80359
# Stage 3 = 55, LL = -7306.8, AR(0.59) = [0.36], gam = 0.0089, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 7 ; time = 27.54436
# Stage 3 = 68, LL = -8772.5, AR(0.45) = [0.40], gam = 0.0076, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 7 ; time = 38.36617
# Stage 3 = 28, LL = -9745.6, AR(0.60) = [0.41], gam = 0.0150, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 7 ; time = 29.41063
# Stage 3 = 54, LL = -12422.3, AR(0.41) = [0.41], gam = 0.0091, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 7 ; time = 47.11176
# Stage 3 = 63, LL = -14949.2, AR(0.30) = [0.39], gam = 0.0080, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 7 ; time = 1.081615
# Stage 3 = 25, LL = -10737.2, AR(0.98) = [0.39], gam = 0.0164, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 7 ; time = 31.25307
# Stage 3 = 39, LL = -14645.4, AR(0.60) = [0.41], gam = 0.0116, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 7 ; time = 48.34071
# Stage 3 = 59, LL = -17347.7, AR(0.48) = [0.39], gam = 0.0085, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 7 ; time = 1.084438
# Stage 3 = 22, LL = -19089.2, AR(0.63) = [0.41], gam = 0.0181, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 7 ; time = 52.65275
# Stage 3 = 30, LL = -24881.6, AR(0.41) = [0.37], gam = 0.0142, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 7 ; time = 1.376281
# Stage 3 = 72, LL = -27878.8, AR(0.40) = [0.36], gam = 0.0073, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 7 ; time = 1.956198
# Stage 3 = 57, LL = -5715.2, AR(1.01) = [0.40], gam = 0.0087, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 7 ; time = 18.45005
# Stage 3 = 86, LL = -6242.3, AR(0.66) = [0.40], gam = 0.0064, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 7 ; time = 27.89427
# Stage 3 = 144, LL = -7526.3, AR(0.52) = [0.38], gam = 0.0043, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 7 ; time = 40.35489
# Stage 3 = 56, LL = -9426.4, AR(0.62) = [0.46], gam = 0.0088, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 7 ; time = 30.39814
# Stage 3 = 82, LL = -11739.8, AR(0.32) = [0.42], gam = 0.0066, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 7 ; time = 48.77768
# Stage 3 = 193, LL = -12965.2, AR(0.37) = [0.40], gam = 0.0034, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 7 ; time = 1.181692
# Stage 3 = 29, LL = -10952.3, AR(0.98) = [0.40], gam = 0.0146, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 7 ; time = 31.92637
# Stage 3 = 36, LL = -13966.7, AR(0.62) = [0.38], gam = 0.0124, Max-Change = 0.0009
#
# Calculating information matrix...
#
# ...
# n = 500 ; j = 20 ; b = 2 ; iter = 8 ; time = 1.316302
# Stage 3 = 68, LL = -8312.9, AR(1.26) = [0.41], gam = 0.0076, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 8 ; time = 32.08645
# Stage 3 = 103, LL = -9937.5, AR(1.10) = [0.34], gam = 0.0055, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 8 ; time = 48.59943
# Stage 3 = 228, LL = -11337.8, AR(0.69) = [0.37], gam = 0.0030, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 8 ; time = 1.18895
# Stage 3 = 97, LL = -12385.4, AR(0.97) = [0.39], gam = 0.0058, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 8 ; time = 55.1592
# Stage 3 = 147, LL = -15314.1, AR(0.66) = [0.39], gam = 0.0042, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 8 ; time = 1.475741
# Stage 3 = 243, LL = -18249.2, AR(0.48) = [0.42], gam = 0.0029, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 8 ; time = 2.174739
# Stage 3 = 30, LL = -5245.9, AR(0.98) = [0.39], gam = 0.0142, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 9 ; time = 18.09199
# Stage 3 = 47, LL = -7528.1, AR(0.59) = [0.41], gam = 0.0101, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 9 ; time = 27.90276
# Stage 3 = 108, LL = -8631.1, AR(0.50) = [0.41], gam = 0.0053, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 9 ; time = 40.4117
# Stage 3 = 29, LL = -8829.4, AR(0.72) = [0.40], gam = 0.0146, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 9 ; time = 30.37874
# Stage 3 = 47, LL = -11959.9, AR(0.26) = [0.46], gam = 0.0101, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 9 ; time = 46.72586
# Stage 3 = 82, LL = -14210.8, AR(0.40) = [0.31], gam = 0.0066, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 9 ; time = 1.096723
# Stage 3 = 27, LL = -11221.3, AR(0.88) = [0.39], gam = 0.0154, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 9 ; time = 31.62175
# Stage 3 = 44, LL = -14410.8, AR(0.59) = [0.42], gam = 0.0106, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 9 ; time = 47.7966
# Stage 3 = 56, LL = -17339.2, AR(0.50) = [0.38], gam = 0.0088, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 9 ; time = 1.098687
# Stage 3 = 17, LL = -19916.3, AR(0.58) = [0.40], gam = 0.0222, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 9 ; time = 52.5449
# Stage 3 = 39, LL = -24959.3, AR(0.50) = [0.36], gam = 0.0116, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 9 ; time = 1.388619
# Stage 3 = 103, LL = -28217.8, AR(0.40) = [0.36], gam = 0.0055, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 9 ; time = 2.027047
# Stage 3 = 29, LL = -5658.9, AR(1.21) = [0.32], gam = 0.0146, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 9 ; time = 18.30756
# Stage 3 = 106, LL = -6467.7, AR(0.72) = [0.38], gam = 0.0054, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 9 ; time = 28.8423
# Stage 3 = 119, LL = -7965.5, AR(0.51) = [0.42], gam = 0.0050, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 9 ; time = 39.71534
# Stage 3 = 41, LL = -9639.0, AR(0.60) = [0.41], gam = 0.0112, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 9 ; time = 29.73177
# Stage 3 = 95, LL = -11940.7, AR(0.43) = [0.42], gam = 0.0059, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 9 ; time = 49.20475
# Stage 3 = 227, LL = -11871.6, AR(0.41) = [0.39], gam = 0.0031, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 9 ; time = 1.211758
# Stage 3 = 35, LL = -10975.8, AR(0.97) = [0.37], gam = 0.0126, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 9 ; time = 31.60694
# Stage 3 = 56, LL = -13525.4, AR(0.69) = [0.41], gam = 0.0088, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 9 ; time = 48.41995
# Stage 3 = 112, LL = -15762.9, AR(0.50) = [0.41], gam = 0.0052, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 9 ; time = 1.125345
# Stage 3 = 33, LL = -18460.2, AR(0.72) = [0.37], gam = 0.0132, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 9 ; time = 54.03232
# Stage 3 = 56, LL = -23817.5, AR(0.32) = [0.47], gam = 0.0088, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 9 ; time = 1.420636
# Stage 3 = 94, LL = -27309.0, AR(0.40) = [0.37], gam = 0.0059, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 9 ; time = 2.021253
# Stage 3 = 92, LL = -3575.5, AR(1.11) = [0.39], gam = 0.0060, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 9 ; time = 18.56635
# Stage 3 = 90, LL = -5573.1, AR(0.72) = [0.38], gam = 0.0061, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 9 ; time = 28.07334
# Stage 3 = 300, LL = -5651.3, AR(0.63) = [0.39], gam = 0.0025, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 9 ; time = 44.99508
# Stage 3 = 109, LL = -6696.6, AR(0.83) = [0.39], gam = 0.0053, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 9 ; time = 31.87005
# Stage 3 = 147, LL = -7458.4, AR(0.59) = [0.37], gam = 0.0042, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 9 ; time = 48.96222
# Stage 3 = 429, LL = -8753.5, AR(0.47) = [0.39], gam = 0.0019, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 9 ; time = 1.408934
# Stage 3 = 124, LL = -6617.9, AR(1.55) = [0.42], gam = 0.0048, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 9 ; time = 33.7317
# Stage 3 = 215, LL = -8788.0, AR(1.21) = [0.33], gam = 0.0032, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 9 ; time = 52.56977
# Stage 3 = 289, LL = -12086.8, AR(0.67) = [0.39], gam = 0.0025, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 9 ; time = 1.233663
# Stage 3 = 80, LL = -13371.1, AR(0.92) = [0.40], gam = 0.0067, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 9 ; time = 54.88177
# Stage 3 = 156, LL = -15533.0, AR(0.69) = [0.38], gam = 0.0040, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 9 ; time = 1.485806
# Stage 3 = 303, LL = -17409.1, AR(0.52) = [0.39], gam = 0.0025, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 9 ; time = 2.287394
# Stage 3 = 36, LL = -5475.9, AR(0.91) = [0.40], gam = 0.0124, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 10 ; time = 18.42667
# Stage 3 = 54, LL = -7246.2, AR(0.60) = [0.42], gam = 0.0091, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 10 ; time = 29.13094
# Stage 3 = 112, LL = -8467.5, AR(0.49) = [0.45], gam = 0.0052, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = -2 ; iter = 10 ; time = 40.39883
# Stage 3 = 25, LL = -10121.2, AR(0.60) = [0.38], gam = 0.0164, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 10 ; time = 30.39593
# Stage 3 = 54, LL = -12383.4, AR(0.50) = [0.36], gam = 0.0091, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 10 ; time = 48.4507
# Stage 3 = 117, LL = -13869.6, AR(0.40) = [0.36], gam = 0.0050, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = -2 ; iter = 10 ; time = 1.136427
# Stage 3 = 25, LL = -9801.8, AR(1.09) = [0.40], gam = 0.0164, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 10 ; time = 30.82448
# Stage 3 = 37, LL = -15093.5, AR(0.59) = [0.38], gam = 0.0121, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 10 ; time = 48.50463
# Stage 3 = 58, LL = -17176.2, AR(0.47) = [0.41], gam = 0.0086, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = -2 ; iter = 10 ; time = 1.109272
# Stage 3 = 23, LL = -18887.4, AR(0.74) = [0.38], gam = 0.0175, Max-Change = 0.0004
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 10 ; time = 52.78045
# Stage 3 = 32, LL = -24995.8, AR(0.50) = [0.35], gam = 0.0135, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 10 ; time = 1.38798
# Stage 3 = 78, LL = -28550.4, AR(0.40) = [0.34], gam = 0.0068, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = -2 ; iter = 10 ; time = 2.02212
# Stage 3 = 29, LL = -5357.8, AR(0.87) = [0.39], gam = 0.0146, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 10 ; time = 18.83563
# Stage 3 = 141, LL = -5858.8, AR(0.65) = [0.41], gam = 0.0044, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 10 ; time = 30.14012
# Stage 3 = 94, LL = -8274.5, AR(0.45) = [0.43], gam = 0.0059, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 0 ; iter = 10 ; time = 39.62844
# Stage 3 = 48, LL = -9345.3, AR(0.62) = [0.43], gam = 0.0099, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 10 ; time = 31.28376
# Stage 3 = 74, LL = -11081.7, AR(0.46) = [0.39], gam = 0.0071, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 10 ; time = 49.34879
# Stage 3 = 185, LL = -13027.0, AR(0.36) = [0.39], gam = 0.0036, Max-Change = 0.0006
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 0 ; iter = 10 ; time = 1.199971
# Stage 3 = 33, LL = -11238.6, AR(0.95) = [0.39], gam = 0.0132, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 10 ; time = 32.85042
# Stage 3 = 47, LL = -13488.5, AR(0.58) = [0.38], gam = 0.0101, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 10 ; time = 50.31924
# Stage 3 = 101, LL = -15891.8, AR(0.51) = [0.37], gam = 0.0056, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 0 ; iter = 10 ; time = 1.14506
# Stage 3 = 33, LL = -17823.5, AR(0.65) = [0.39], gam = 0.0132, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 10 ; time = 54.87641
# Stage 3 = 58, LL = -24294.4, AR(0.50) = [0.35], gam = 0.0086, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 10 ; time = 1.437101
# Stage 3 = 129, LL = -23967.9, AR(0.50) = [0.32], gam = 0.0047, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 0 ; iter = 10 ; time = 2.067743
# Stage 3 = 66, LL = -4362.0, AR(0.99) = [0.42], gam = 0.0078, Max-Change = 0.0005
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 10 ; time = 19.39541
# Stage 3 = 220, LL = -4707.0, AR(0.88) = [0.37], gam = 0.0031, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 10 ; time = 30.98648
# Stage 3 = 348, LL = -5093.4, AR(0.62) = [0.36], gam = 0.0022, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 10 ; b = 2 ; iter = 10 ; time = 45.95126
# Stage 3 = 111, LL = -5525.4, AR(0.99) = [0.41], gam = 0.0052, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 10 ; time = 32.19224
# Stage 3 = 277, LL = -7195.3, AR(0.68) = [0.42], gam = 0.0026, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 10 ; time = 53.86188
# Stage 3 = 305, LL = -8338.1, AR(0.52) = [0.39], gam = 0.0024, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 500 ; j = 20 ; b = 2 ; iter = 10 ; time = 1.343586
# Stage 3 = 75, LL = -7246.6, AR(1.47) = [0.40], gam = 0.0070, Max-Change = 0.0007
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 10 ; time = 32.74931
# Stage 3 = 236, LL = -9808.1, AR(0.95) = [0.39], gam = 0.0030, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 10 ; time = 55.63126
# Stage 3 = 244, LL = -11857.8, AR(0.68) = [0.38], gam = 0.0029, Max-Change = 0.0010
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 10 ; b = 2 ; iter = 10 ; time = 1.208654
# Stage 3 = 85, LL = -11499.8, AR(1.01) = [0.39], gam = 0.0064, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 10 ; time = 55.91051
# Stage 3 = 207, LL = -12434.0, AR(0.79) = [0.41], gam = 0.0033, Max-Change = 0.0009
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 10 ; time = 1.54652
# Stage 3 = 274, LL = -16740.3, AR(0.52) = [0.38], gam = 0.0026, Max-Change = 0.0008
#
# Calculating information matrix...
#
# Calculating log-likelihood...
# n = 1000 ; j = 20 ; b = 2 ; iter = 10 ; time = 2.245084

# %%
# Out:
# Error: Clipboard on X11 requires that the DISPLAY envvar be configured.
# Traceback:
#
# 1. clipr::write_clip(rdf, allow_non_interactive = T)
# 2. chosen_write_clip(content, object_type, breaks, eos, return_new,
#  .     ...)
# 3. has_xsel()
# 4. has_util(c("xsel", "--clipboard", "--output"))
# 5. notify_no_display()
# 6. stop(msg_no_display(), call. = FALSE)

# %%
int <- nrow(rdf) / 10
for (i in 1:10) {
  cases <- (int*(i-1)+1):(i*int)
  df <- rdf[cases,]
  write.csv(df, paste0("out", i, ".csv"))
  #print(cases)
}

# %%
for (i in 1:10) {}
